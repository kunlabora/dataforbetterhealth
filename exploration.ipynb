# %%
import pandas as pd
import numpy as np

from lib.pipepy.pipepy.core import Pipeline

# %%
pop = pd.read_csv('data/statbel/TF_SOC_POP_STRUCT_2018.txt', delimiter='|')
# Out:
# /Users/tomdke/.virtualenvs/py3_data_science/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pop.describe()
# Out:
#        CD_MUNTY_REFNIS  CD_DSTR_REFNIS  CD_RGN_REFNIS     CD_CIV_STS  \
# count    465418.000000   465418.000000  465418.000000  465418.000000
# mean      45795.085029    45754.592646    2517.923673      22.086554
# std       23956.614057    23950.946921     584.591526      11.218918
# min       11001.000000    11000.000000    2000.000000      10.000000
# 25%       24033.000000    24000.000000    2000.000000      10.000000
# 50%       44043.000000    44000.000000    2000.000000      20.000000
# 75%       63035.000000    63000.000000    3000.000000      30.000000
# max       93090.000000    93000.000000    4000.000000      40.000000
#
#               CD_AGE  MS_POPULATION   CD_YEAR
# count  465418.000000  465418.000000  465418.0
# mean       52.607527      24.442695    2018.0
# std        23.467469      63.746827       0.0
# min         0.000000       1.000000    2018.0
# 25%        35.000000       2.000000    2018.0
# 50%        53.000000       7.000000    2018.0
# ...

# %%
inkomen = pd.read_csv('data/statbel/TF_PSNL_INC_TAX_MUNTY.txt', delimiter='|')

# %%
inkomen.describe()
# Out:
#            CD_YEAR  CD_MUNTY_REFNIS  MS_NBR_NON_ZERO_INC  MS_NBR_ZERO_INC  \
# count  7068.000000      7068.000000          7068.000000      7068.000000
# mean   2010.500000     47163.312394         10453.895444       965.616582
# std       3.452297     24208.761550         16972.829121      2320.295816
# min    2005.000000     11001.000000            49.000000         0.000000
# 25%    2007.750000     24107.000000          3951.500000       252.000000
# 50%    2010.500000     45041.000000          6644.500000       437.000000
# 75%    2013.250000     63076.000000         11324.250000       805.250000
# max    2016.000000     93090.000000        290027.000000     38292.000000
#
#        MS_TOT_NET_TAXABLE_INC  MS_TOT_NET_INC  MS_NBR_TOT_NET_INC  \
# count            7.068000e+03    7.068000e+03         7068.000000
# mean             2.976507e+08    3.017776e+08        10453.895444
# std              4.404818e+08    4.465664e+08        16972.829121
# ...
